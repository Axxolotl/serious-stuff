# %%
# судя по всему, для парсинга расписания нам понадобиться доставать инфу через selenium
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.support.select import Select
from selenium.webdriver.chrome.options import Options

import time

# создаем драйвер
# следующие две строчки нужны для того, чтобы браузер не открывался
chrome_options = Options()
# chrome_options.add_argument("--headless")
driver = webdriver.Chrome(ChromeDriverManager().install(), options=chrome_options)

# url сайта рггу
url = 'https://www.rsuh.ru/raspis/'
driver.get(url)
time.sleep(2)

# просим пользователя ввести интересующие данные (в боте нужно будет по-другому это делать)
edu_form = input('Введите форму обучения: ')
course_num = input('Введите курс обучения: ')
period = input('Введите срок: ')
speciality = input('Введите название вашей специальности: ')

# в общем тут мы просто выставляем значения у выпадающих списков
for i in zip(['formob', 'kyrs', 'srok'], [edu_form, course_num, period]):
    select = Select(driver.find_element(By.ID, i[0]))
    select.select_by_visible_text(i[1])

# жмякаем на кнопку "продолжить"
continue_ = driver.find_element(By.ID, 'filters').click()
time.sleep(2)

# заполняем название группы
group = driver.find_element(By.NAME, 'fprep')
group.send_keys(speciality)

# жмякаем на кнопку "получить расписание"
get_raspis = driver.find_element(By.NAME, 'potokbut2').click()
time.sleep(2)

# записываем данные с появляющейся таблички в список data
data = []
for tr in driver.find_elements(By.XPATH, '//*[@id="dop2"]/table//tr'):
    tds = tr.find_elements(By.TAG_NAME, 'td')
    data.append([td.text for td in tds])
# Out:
# C:\Users\petti\AppData\Local\Temp/ipykernel_4696/2839940371.py:14: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options=chrome_options)
# Введите форму обучения: Дневная
# Введите курс обучения: Курс 4
# Введите срок: На неделю
# Введите название вашей специальности: оис
# [['Дата', 'Пара', 'Группа', 'П\\гр', 'Аудит', 'Предмет', 'Тип', 'Лектор'],
#  ['13.10.2022 ЧТ',
#   '3',
#   '-',
#   '-',
#   '309(2)',
#   'Второй иностранный язык',
#   'сем',
#   'Прилепская М.В.'],
#  ['704(2)', 'Второй иностранный язык', 'сем', 'Мастяница М.С.'],
#  ['4',
#   '-',
#   '-',
#   '309(2)',
#   'Второй иностранный язык',
#   'сем',
#   'Прилепская М.В.'],
#  ['428а', 'Второй иностранный язык', 'сем', 'Тамайо Кабрера'],
#  ['704(2)', 'Второй иностранный язык', 'сем', 'Мастяница М.С.'],
#  ['5', '-', '-', '-', 'Спец. занятость', 'спец', '-'],
#  ['6', '-', '-', '-', 'Спец. занятость', 'спец', '-'],
#  ['14.10.2022 ПТ',
#   '1',
#   '-',
#   '-',
#   '428а',
#   'Второй иностранный язык',
#   'сем',
#   'Тамайо Кабрера'],
#  ['2', '-', '-', '428а', 'Второй иностранный язык', 'сем', 'Тамайо Кабрера'],
#  ['3', '-', '-', '-', 'Спец. занятость', 'спец', '-'],
#  ['4',
#   '-',
#   '-',
#   'ИИНТБ',
#   'Элективные дисциплины по физической культуре и спорту',
#   'сем',
#   '-'],
#  ['5', '-', '-', '-', 'Спец. занятость', 'спец', '-'],
#  ['17.10.2022 ПН',
#   '3',
#   '-',
#   '-',
#   '706(2)КК',
#   'Алгебраические методы в информатике',
#   'сем',
#   'Стефановский Д.В.'],
#  ['4',
#   '-',
#   '-',
#   '706(2)КК',
#   'Алгебраические методы в информатике',
#   'сем',
#   'Стефановский Д.В.'],
#  ['5',
#   '-',
#   '-',
#   '410(2)',
#   'Генетические алгоритмы и нейросети',
#   'сем',
#   'Шашкин Л.О.'],
#  ['805(2)', 'Нечеткие множества', 'сем', 'Аншаков О.М.'],
#  ['6',
#   '-',
#   '-',
#   '410(2)',
#   'Генетические алгоритмы и нейросети',
#   'сем',
#   'Шашкин Л.О.'],
#  ['805(2)', 'Нечеткие множества', 'сем', 'Аншаков О.М.'],
#  ['18.10.2022 ВТ',
#   '2',
#   '-',
#   '-',
#   '804(2)',
#   'Вычислительная лингвистика',
#   'лек',
#   'Пентус М.Р.'],
#  ['706(2)КК', 'Онтологии в представлении знаний', 'лек', 'Стефановский Д.В.'],
#  ['3',
#   '-',
#   '-',
#   '606(5)',
#   'История развития систем искусственного интеллекта',
#   'сем',
#   'Аншаков О.М.'],
#  ['410(2)',
#   'Методология разработки интеллектуальных систем',
#   'сем',
#   'Стефановский Д.В.'],
#  ['4',
#   '-',
#   '-',
#   '606(5)',
#   'История развития систем искусственного интеллекта',
#   'сем',
#   'Аншаков О.М.'],
#  ['410(2)',
#   'Методология разработки интеллектуальных систем',
#   'сем',
#   'Стефановский Д.В.'],
#  ['5',
#   '-',
#   '-',
#   '427',
#   'История развития систем искусственного интеллекта',
#   'лек',
#   'Аншаков О.М.'],
#  ['19.10.2022 СР',
#   '1',
#   '-',
#   '-',
#   '307(2)',
#   'Введение в робототехнику',
#   'лек',
#   'Павловский В.В.'],
#  ['2',
#   '-',
#   '-',
#   '307(2)',
#   'Введение в робототехнику',
#   'лек',
#   'Павловский В.В.'],
#  ['3',
#   '-',
#   '-',
#   '706(2)КК',
#   'Языки запросов к базам данных и онтологиям',
#   'лек',
#   'Стефановский Д.В.'],
#  ['4',
#   '-',
#   '-',
#   '706(2)КК',
#   'Языки запросов к базам данных и онтологиям',
#   'лек',
#   'Стефановский Д.В.'],
#  ['20.10.2022 ЧТ',
#   '3',
#   '-',
#   '-',
#   '309(2)',
#   'Второй иностранный язык',
#   'сем',
#   'Прилепская М.В.'],
#  ['704(2)', 'Второй иностранный язык', 'сем', 'Мастяница М.С.'],
#  ['4',
#   '-',
#   '-',
#   '309(2)',
#   'Второй иностранный язык',
#   'сем',
#   'Прилепская М.В.'],
#  ['704(2)', 'Второй иностранный язык', 'сем', 'Мастяница М.С.'],
#  ['5',
#   '1',
#   '1',
#   '307(2)',
#   'Компонентное программирование в Windows',
#   'лаб',
#   'Епифанов М.Е.'],
#  ['2',
#   '307(2)',
#   'Компонентное программирование в Windows',
#   'лаб',
#   'Епифанов М.Е.'],
#  ['6',
#   '1',
#   '1',
#   '307(2)',
#   'Компонентное программирование в Windows',
#   'лаб',
#   'Епифанов М.Е.'],
#  ['2',
#   '307(2)',
#   'Компонентное программирование в Windows',
#   'лаб',
#   'Епифанов М.Е.']]

# %%
# я хочу загрузить полученные данные в pandas.DataFrame. В таблицу то есть.
import pandas as pd

# создаем датафрейм с расписанием, в качестве названий колонок берем первую строку 
data_frame = pd.DataFrame(columns=data[0])

# дальше будем добавлять в датасет данные
for i in data[1:]:
    
    # если длина списка равна 8, то он полный, поэтому дополнительно сохраним все эти строчки, потому что у некоторых строчек
    # обрезана информация, наверное, чтобы не повторяться
    # ИЛИ ПОТОМУ ЧТО РАЗРАБЫ ЕБЛАНЫ НУ КТО НАЗЫВАЕТ СУЩНОСТИ РУССКИМИ СЛОВАМИ АНГЛИЙСКИМИ БУКВАМИ БЛЯЯЯЯЯТЬ
    # тильт
    if len(i)==8:
        full_info = i
        data_frame.loc[len(data_frame.index)] = i
        
    # если список неполный, мы добавляем к нему информацию предыдущей пары
    else:
        data_frame.loc[len(data_frame.index)] = list(data_frame.loc[len(data_frame.index)-1][:8-len(i)]) + i
        
data_frame
# Out:
#              Дата Пара Группа П\гр     Аудит  \
# 0   13.10.2022 ЧТ    3      -    -    309(2)
# 1   13.10.2022 ЧТ    3      -    -    704(2)
# 2   13.10.2022 ЧТ    4      -    -    309(2)
# 3   13.10.2022 ЧТ    4      -    -      428а
# 4   13.10.2022 ЧТ    4      -    -    704(2)
# 5   13.10.2022 ЧТ    5      -    -         -
# 6   13.10.2022 ЧТ    6      -    -         -
# 7   14.10.2022 ПТ    1      -    -      428а
# 8   14.10.2022 ПТ    2      -    -      428а
# 9   14.10.2022 ПТ    3      -    -         -
# 10  14.10.2022 ПТ    4      -    -     ИИНТБ
# 11  14.10.2022 ПТ    5      -    -         -
# 12  17.10.2022 ПН    3      -    -  706(2)КК
# 13  17.10.2022 ПН    4      -    -  706(2)КК
# 14  17.10.2022 ПН    5      -    -    410(2)
# 15  17.10.2022 ПН    5      -    -    805(2)
# 16  17.10.2022 ПН    6      -    -    410(2)
# 17  17.10.2022 ПН    6      -    -    805(2)
# 18  18.10.2022 ВТ    2      -    -    804(2)
# 19  18.10.2022 ВТ    2      -    -  706(2)КК
# 20  18.10.2022 ВТ    3      -    -    606(5)
# 21  18.10.2022 ВТ    3      -    -    410(2)
# 22  18.10.2022 ВТ    4      -    -    606(5)
# 23  18.10.2022 ВТ    4      -    -    410(2)
# 24  18.10.2022 ВТ    5      -    -       427
# 25  19.10.2022 СР    1      -    -    307(2)
# 26  19.10.2022 СР    2      -    -    307(2)
# 27  19.10.2022 СР    3      -    -  706(2)КК
# 28  19.10.2022 СР    4      -    -  706(2)КК
# 29  20.10.2022 ЧТ    3      -    -    309(2)
# 30  20.10.2022 ЧТ    3      -    -    704(2)
# 31  20.10.2022 ЧТ    4      -    -    309(2)
# 32  20.10.2022 ЧТ    4      -    -    704(2)
# 33  20.10.2022 ЧТ    5      1    1    307(2)
# 34  20.10.2022 ЧТ    5      1    2    307(2)
# 35  20.10.2022 ЧТ    6      1    1    307(2)
# 36  20.10.2022 ЧТ    6      1    2    307(2)
#
#                                               Предмет   Тип             Лектор
# 0                             Второй иностранный язык   сем    Прилепская М.В.
# 1                             Второй иностранный язык   сем     Мастяница М.С.
# 2                             Второй иностранный язык   сем    Прилепская М.В.
# 3                             Второй иностранный язык   сем     Тамайо Кабрера
# 4                             Второй иностранный язык   сем     Мастяница М.С.
# 5                                     Спец. занятость  спец                  -
# 6                                     Спец. занятость  спец                  -
# 7                             Второй иностранный язык   сем     Тамайо Кабрера
# 8                             Второй иностранный язык   сем     Тамайо Кабрера
# 9                                     Спец. занятость  спец                  -
# 10  Элективные дисциплины по физической культуре и...   сем                  -
# 11                                    Спец. занятость  спец                  -
# 12                Алгебраические методы в информатике   сем  Стефановский Д.В.
# 13                Алгебраические методы в информатике   сем  Стефановский Д.В.
# 14                 Генетические алгоритмы и нейросети   сем        Шашкин Л.О.
# 15                                 Нечеткие множества   сем       Аншаков О.М.
# 16                 Генетические алгоритмы и нейросети   сем        Шашкин Л.О.
# 17                                 Нечеткие множества   сем       Аншаков О.М.
# 18                         Вычислительная лингвистика   лек        Пентус М.Р.
# 19                   Онтологии в представлении знаний   лек  Стефановский Д.В.
# 20  История развития систем искусственного интеллекта   сем       Аншаков О.М.
# 21     Методология разработки интеллектуальных систем   сем  Стефановский Д.В.
# 22  История развития систем искусственного интеллекта   сем       Аншаков О.М.
# 23     Методология разработки интеллектуальных систем   сем  Стефановский Д.В.
# 24  История развития систем искусственного интеллекта   лек       Аншаков О.М.
# 25                           Введение в робототехнику   лек    Павловский В.В.
# 26                           Введение в робототехнику   лек    Павловский В.В.
# 27         Языки запросов к базам данных и онтологиям   лек  Стефановский Д.В.
# 28         Языки запросов к базам данных и онтологиям   лек  Стефановский Д.В.
# 29                            Второй иностранный язык   сем    Прилепская М.В.
# 30                            Второй иностранный язык   сем     Мастяница М.С.
# 31                            Второй иностранный язык   сем    Прилепская М.В.
# 32                            Второй иностранный язык   сем     Мастяница М.С.
# 33            Компонентное программирование в Windows   лаб      Епифанов М.Е.
# 34            Компонентное программирование в Windows   лаб      Епифанов М.Е.
# 35            Компонентное программирование в Windows   лаб      Епифанов М.Е.
# 36            Компонентное программирование в Windows   лаб      Епифанов М.Е.
